# %%
misplaced_times=[0, 0.00012111663818359375, 0.00019502639770507812, 0.0006530284881591797, 0.0036978721618652344, 0.01631784439086914, 0.07966208457946777, 0.4852571487426758]
manhattan_times=[0, 0.00011110305786132812, 0.00022077560424804688, 0.0005249977111816406, 0.0012590885162353516, 0.0029480457305908203, 0.013712167739868164, 0.04815816879272461]
uniform_time= [0, 0.00021910667419433594, 0.0009829998016357422, 0.008659124374389648, 0.0500028133392334, 0.29721522331237793, 1.463709831237793, 4.2634031772613525]

misplaced_nodes_expanded = [0, 2, 4, 19, 131, 701, 3299, 18451]
manhattan_nodes_expanded = [0, 2, 4, 12, 36, 95, 499, 1757]
uniform_nodes_expanded = [0, 6, 32, 310, 2327, 13709, 54665, 135273]

misplaced_max_queue = [0, 4, 9, 33, 144, 695, 3293, 16729]
manhattan_max_queue = [0, 4, 9, 23, 50, 103, 530, 1901]
uniform_max_queue = [0, 12, 42, 331, 2341, 12807, 41195, 61384]

# %%
import matplotlib.pyplot as plt

# Three lists of values
x = [0, 2, 4, 8, 12, 16, 20, 24]
y1 = misplaced_times
y2 = manhattan_times
y3 = uniform_time

# Create the plot
plt.plot(x, y1, color='red', label='Misplaced_tiles')
plt.plot(x, y2, color='blue', label='Manhattan Distance')
plt.plot(x, y3, color='green', label='Uniform Cost Search')

# Set the plot title and labels
plt.title('Running time vs Solution depth')
plt.xlabel('Solution Depth')
plt.ylabel('Time Taken (sec)')
plt.xticks(x)
# Add a legend
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Three lists of values
x = [0, 2, 4, 8, 12, 16, 20, 24]
y1 = misplaced_max_queue
y2 = manhattan_max_queue
y3 = uniform_max_queue

# Create the plot
plt.plot(x, y1, color='red', label='Misplaced_tiles')
plt.plot(x, y2, color='blue', label='Manhattan Distance')
plt.plot(x, y3, color='green', label='Uniform Cost Search')

# Set the plot title and labels
plt.title('Max Queue Size vs Solution depth')
plt.xlabel('Solution Depth')
plt.ylabel('Max Queue Size')
plt.xticks(x)
# Add a legend
plt.legend()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Three lists of values
x = [0, 2, 4, 8, 12, 16, 20, 24]
y1 = misplaced_nodes_expanded
y2 = manhattan_nodes_expanded
y3 = uniform_nodes_expanded

# Create the plot
plt.plot(x, y1, color='red', label='Misplaced_tiles')
plt.plot(x, y2, color='blue', label='Manhattan Distance')
plt.plot(x, y3, color='green', label='Uniform Cost Search')

# Set the plot title and labels
plt.title('Total Nodes Expanded vs Solution depth')
plt.xlabel('Solution Depth')
plt.ylabel('Total Nodes')
plt.xticks(x)
# Add a legend
plt.legend()

# Display the plot
plt.show()
